# %%
#--*--econding:utf-8--*--
import requests,re
# import pytests

def pre_fenlei_list():
   
    """请求参数准备"""
    url = "http://www.xiaoqiang520.cc"
    params = {
        "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
        "Accept-Encoding":"gzip, deflate",
        "Accept-Language":"zh-CN,zh;q=0.8,zh-TW;q=0.7,zh-HK;q=0.5,en-US;q=0.3,en;q=0.2",
        "Cache-Control":"max-age=0",
#         "Alt-Used":"www.xiaoqiang520.cc:443",
        "Connection":"keep-alive",
        "Cookie":"__cfduid=d224cb60b4ce781704e1a7b2e7f8054981617025838; UM_distinctid=1787e40427e3d-0b0a5541c24bfe-7e22675c-1fa400-1787e404285d6; CNZZDATA1262405446=363641120-1617022671-https%253A%252F%252Fwww.baidu.com%252F%7C1617022671",       
        "Host":"www.xiaoqiang520.cc",
        "Referer":"http://www.xiaoqiang520.cc/fenlei/1_1.html",
        "Upgrade-Insecure-Requests":"1",
        "User-Agent":"Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:87.0) Gecko/20100101 Firefox/87.0"
    }
    #获取首页html
    text = requests.get(url, params=params).text
    fenlei_parten = r"./fenlei/d_1.html.>都市青春</a>"
    fenlei = re.compile(fenlei_partenen)
    fl_list = fenlei.findall(text)
    print(fl_list)


def get_one_fenlei():
    pass

    
if __name__ == "__main__":
    print(pre_fenlei_list())
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~/.virtualenvs/venv1/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~/.virtualenvs/venv1/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ...
